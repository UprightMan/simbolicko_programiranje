# %%
import sympy, numpy, math

# %%
x = (numpy.e**(1/numpy.pi) + numpy.pi**(1/numpy.e))/(numpy.pi + numpy.e)
print(x)
# Out:
# 0.49463060875748865

# %%
sympy.solve((sympy.root(numpy.e, sympy.pi) + sympy.root(sympy.pi, numpy.e)) / (sympy.pi+numpy.e))
# Out:
# []

# %%
n = 10
y = 1
while n < 100:
    if sympy.isprime(2**n -1) == True:
        y = n
    n+=1
y
# Out:
# 89

# %%
sympy.plotting.plot((28245729) / (10390586+sympy.Symbol('k')) - numpy.e)

# %%
(28245729) / (10390586 + 2) - numpy.e
# Out:
# 0.00011380035426178381

# %%
sympy.solve(sympy.sin(sympy.Symbol("x"))== 2)
# Out:
# []
